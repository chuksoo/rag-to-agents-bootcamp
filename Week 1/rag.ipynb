# %%
from openai import OpenAI

openai_client = OpenAI()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from openai import OpenAI
#       3 openai_client = OpenAI()
#
# ModuleNotFoundError: No module named 'openai'

# %%
def llm(user_prompt, instructions=None, model="gpt-4o-mini"):
    messages = []

    if instructions:
        messages.append({
            "role": "system",
            "content": instructions
        })

    messages.append({
        "role": "user",
        "content": user_prompt
    })

    response = openai_client.responses.create(
        model=model,
        input=messages
    )

    return response.output_text

# %%
llm('When does the course start?')
# Out:
# "Could you provide more details about the course you're asking about? That way, I can assist you better!"

# %% [markdown]
# #### Read in FAQ documents

# %%
import requests 

docs_url = 'https://github.com/alexeygrigorev/llm-rag-workshop/raw/main/notebooks/documents.json'
docs_response = requests.get(docs_url)
documents_raw = docs_response.json()

documents = []

for course in documents_raw:
    course_name = course['course']

    for doc in course['documents']:
        doc['course'] = course_name
        documents.append(doc)

# %%
documents[11]
# Out:
# {'text': "No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running.",
#  'section': 'General course-related questions',
#  'question': 'Certificate - Can I follow the course in a self-paced mode and get a certificate?',
#  'course': 'data-engineering-zoomcamp'}

# %%
len(documents)
# Out:
# 948

# %% [markdown]
# ## Text Search

# %%
from minsearch import Index

# %%
index = Index(
    text_fields=["question", "text", "section"],
    keyword_fields=["course"]
)

index.fit(documents)

# %%
def search(question):
    return index.search(
        question,
        boost_dict={'question': 3.0, 'section': 0.3},
        filter_dict={'course': 'data-engineering-zoomcamp'},
        num_results=5
    )

# %%
question = 'I just discovered the course, can I join now?'

# %%
search_results = search(question)

# %%
instructions = """
You're a course teaching assistant. Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
""".strip()

prompt_template = """
<QUESTION>
{question}
</QUESTION>

<CONTEXT>
{context}
</CONTEXT>
""".strip()

# %%
import json

# %%
def build_prompt(question, search_results):
    search_json = json.dumps(search_results)
    return prompt_template.format(
        question=question,
        context=search_json
    )

# %%
def rag(question):
    search_results = search(question)
    user_prompt = build_prompt(question, search_results)
    return llm(user_prompt, instructions=instructions)

# %%
question = 'I just discovered the course, can I join now?'
rag(question)
# Out:
# "Yes, you can join the course even after it has started. You are eligible to submit the homeworks; however, be mindful that there will be deadlines for the final projects. It's advisable not to leave everything until the last minute."

# %% [markdown]
# ## Vector search

# %%
# !uv add sentence-transformers
# Out:
# Resolved 151 packages in 2.46s
# ⠙ Preparing packages... (0/30)                                                  ⠋ Preparing packages... (0/0)
# ⠙ Preparing packages... (0/30)-------------     0 B/194.62 KiB
# ⠙ Preparing packages... (0/30)------------- 14.88 KiB/194.62 KiB
# ⠙ Preparing packages... (0/30)------------- 14.88 KiB/194.62 KiB
# fsspec               ------------------------------ 14.88 KiB/194.62 KiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec               ------------------------------ 14.88 KiB/194.62 KiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec               ------------------------------ 14.88 KiB/194.62 KiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec               ------------------------------ 14.88 KiB/194.62 KiB
# tokenizers           ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec               ------------------------------ 14.88 KiB/194.62 KiB
# tokenizers           ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec               ------------------------------ 14.88 KiB/194.62 KiB
# tokenizers           ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec               ------------------------------ 14.88 KiB/194.62 KiB
# tokenizers           ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec               ------------------------------ 14.88 KiB/194.62 KiB
# nvidia-cufile-cu12   ------------------------------     0 B/1.14 MiB
# tokenizers           ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec               ------------------------------ 14.88 KiB/194.62 KiB
# nvidia-cufile-cu12   ------------------------------     0 B/1.14 MiB
# tokenizers               ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec                   ------------------------------ 14.88 KiB/194.62 KiB
# nvidia-cufile-cu12   ------------------------------     0 B/1.14 MiB
# tokenizers               ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec                   ------------------------------ 14.88 KiB/194.62 KiB
# nvidia-cufile-cu12       ------------------------------     0 B/1.14 MiB
# tokenizers               ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-------------     0 B/11.44 MiB
# fsspec                   ------------------------------ 14.88 KiB/194.62 KiB
# nvidia-cufile-cu12       ------------------------------     0 B/1.14 MiB
# tokenizers               ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-----------------     0 B/11.44 MiB
# fsspec                   ------------------------------ 14.88 KiB/194.62 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/932.39 KiB
# nvidia-cufile-cu12       ------------------------------     0 B/1.14 MiB
# tokenizers               ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)-----------------     0 B/11.44 MiB
# fsspec                   ------------------------------ 14.88 KiB/194.62 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/932.39 KiB
# nvidia-cufile-cu12       ------------------------------     0 B/1.14 MiB
# tokenizers               ------------------------------     0 B/3.10 MiB
# ⠙ Preparing packages... (0/30)----------------- 14.87 KiB/11.44 MiB
# fsspec                   ------------------------------ 14.88 KiB/194.62 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/932.39 KiB
# nvidia-cufile-cu12       ------------------------------     0 B/1.14 MiB
# tokenizers               ------------------------------ 14.91 KiB/3.10 MiB
# ⠙ Preparing packages... (0/30)----------------- 14.87 KiB/11.44 MiB
# fsspec                   ------------------------------ 14.88 KiB/194.62 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.89 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 14.90 KiB/1.14 MiB
# networkx                 ------------------------------     0 B/1.94 MiB
# hf-xet                   ------------------------------     0 B/3.04 MiB
# tokenizers               ------------------------------ 14.91 KiB/3.10 MiB
# nvidia-cuda-cupti-cu12   ------------------------------     0 B/9.77 MiB
# transformers             ------------------------------ 14.87 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------     0 B/37.44 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------     0 B/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------     0 B/118.88 MiB
# triton                   ------------------------------     0 B/162.58 MiB
# nvidia-cusolver-cu12     ------------------------------ 14.82 KiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------     0 B/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------     0 B/274.86 MiB
# nvidia-nccl-cu12         ------------------------------     0 B/307.42 MiB
# nvidia-cublas-cu12       ------------------------------ 14.82 KiB/566.81 MiB
# ⠙ Preparing packages... (0/30)----------------     0 B/674.02 MiB
# fsspec                   ------------------------------ 30.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# huggingface-hub          ------------------------------ 14.87 KiB/551.04 KiB
# regex                    ------------------------------ 14.91 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.89 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 46.79 KiB/1.14 MiB
# networkx                 ------------------------------ 14.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 14.91 KiB/3.04 MiB
# tokenizers               ------------------------------ 14.91 KiB/3.10 MiB
# sympy                    ------------------------------ 14.88 KiB/6.01 MiB
# pillow                   ------------------------------ 14.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 14.89 KiB/9.77 MiB
# transformers             ------------------------------ 30.87 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 16.00 KiB/37.44 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 14.89 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 2.85 KiB/118.88 MiB
# triton                   ------------------------------ 14.88 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 14.82 KiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 14.82 KiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 14.82 KiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 14.82 KiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 14.83 KiB/307.42 MiB
# ⠙ Preparing packages... (0/30)---------------- 14.82 KiB/566.81 MiB
# filelock                 ------------------------------ 8.79 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 14.90 KiB/87.85 KiB
# fsspec                   ------------------------------ 30.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 16.00 KiB/475.17 KiB
# mpmath                   ------------------------------ 14.84 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 14.87 KiB/551.04 KiB
# regex                    ------------------------------ 42.97 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.89 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 77.36 KiB/1.14 MiB
# networkx                 ------------------------------ 14.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 14.91 KiB/3.04 MiB
# tokenizers               ------------------------------ 14.91 KiB/3.10 MiB
# sympy                    ------------------------------ 14.88 KiB/6.01 MiB
# pillow                   ------------------------------ 14.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 14.89 KiB/9.77 MiB
# transformers             ------------------------------ 30.87 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 16.00 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 14.89 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 14.89 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 2.85 KiB/118.88 MiB
# triton                   ------------------------------ 14.88 KiB/162.58 MiB
# ⠹ Preparing packages... (0/30)---------------- 14.82 KiB/184.17 MiB
# filelock                 ------------------------------ 8.79 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 14.90 KiB/87.85 KiB
# fsspec                   ------------------------------ 30.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 16.00 KiB/475.17 KiB
# mpmath                   ------------------------------ 14.84 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 14.87 KiB/551.04 KiB
# regex                    ------------------------------ 110.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.89 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 141.36 KiB/1.14 MiB
# networkx                 ------------------------------ 14.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 14.91 KiB/3.04 MiB
# tokenizers               ------------------------------ 14.91 KiB/3.10 MiB
# sympy                    ------------------------------ 14.88 KiB/6.01 MiB
# pillow                   ------------------------------ 14.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 14.89 KiB/9.77 MiB
# transformers             ------------------------------ 62.87 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 16.00 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 14.89 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 14.89 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 2.85 KiB/118.88 MiB
# triton                   ------------------------------ 141.82 KiB/162.58 MiB
# ⠹ Preparing packages... (0/30)---------------- 14.82 KiB/184.17 MiB
# filelock                 ------------------------------ 8.79 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 14.90 KiB/87.85 KiB
# fsspec                   ------------------------------ 30.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 32.00 KiB/475.17 KiB
# mpmath                   ------------------------------ 14.84 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 30.87 KiB/551.04 KiB
# regex                    ------------------------------ 158.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 28.49 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 205.36 KiB/1.14 MiB
# networkx                 ------------------------------ 14.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 188.07 KiB/3.04 MiB
# tokenizers               ------------------------------ 14.91 KiB/3.10 MiB
# sympy                    ------------------------------ 14.88 KiB/6.01 MiB
# pillow                   ------------------------------ 14.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 14.89 KiB/9.77 MiB
# transformers             ------------------------------ 62.87 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 16.00 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 14.89 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 14.89 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 14.83 KiB/118.88 MiB
# triton                   ------------------------------ 189.82 KiB/162.58 MiB
# ⠹ Preparing packages... (0/30)---------------- 14.82 KiB/184.17 MiB
# filelock                 ------------------------------ 8.79 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 14.90 KiB/87.85 KiB
# fsspec                   ------------------------------ 30.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 32.00 KiB/475.17 KiB
# mpmath                   ------------------------------ 14.84 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 30.87 KiB/551.04 KiB
# regex                    ------------------------------ 158.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 28.49 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 205.36 KiB/1.14 MiB
# networkx                 ------------------------------ 14.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 237.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 14.91 KiB/3.10 MiB
# sympy                    ------------------------------ 14.88 KiB/6.01 MiB
# pillow                   ------------------------------ 14.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 14.89 KiB/9.77 MiB
# transformers             ------------------------------ 75.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 231.08 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 14.89 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 14.89 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 30.83 KiB/118.88 MiB
# triton                   ------------------------------ 253.82 KiB/162.58 MiB
# ⠸ Preparing packages... (0/30)---------------- 14.82 KiB/184.17 MiB
# filelock                 ------------------------------ 8.79 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 14.90 KiB/87.85 KiB
# fsspec                   ------------------------------ 30.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 48.00 KiB/475.17 KiB
# mpmath                   ------------------------------ 30.84 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 30.87 KiB/551.04 KiB
# regex                    ------------------------------ 206.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 28.49 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 253.36 KiB/1.14 MiB
# networkx                 ------------------------------ 30.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 237.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 14.91 KiB/3.10 MiB
# sympy                    ------------------------------ 30.88 KiB/6.01 MiB
# pillow                   ------------------------------ 14.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 14.89 KiB/9.77 MiB
# transformers             ------------------------------ 75.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 231.08 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 14.89 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 219.20 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 30.83 KiB/118.88 MiB
# triton                   ------------------------------ 253.82 KiB/162.58 MiB
# ⠸ Preparing packages... (0/30)---------------- 14.82 KiB/184.17 MiB
# filelock                 ------------------------------ 8.79 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 14.90 KiB/87.85 KiB
# fsspec                   ------------------------------ 46.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 61.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 125.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 30.87 KiB/551.04 KiB
# regex                    ------------------------------ 242.61 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 219.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 301.44 KiB/1.14 MiB
# networkx                 ------------------------------ 30.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 301.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 30.91 KiB/3.10 MiB
# sympy                    ------------------------------ 30.88 KiB/6.01 MiB
# pillow                   ------------------------------ 14.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 62.89 KiB/9.77 MiB
# transformers             ------------------------------ 75.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 284.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 30.89 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 267.20 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 30.83 KiB/118.88 MiB
# triton                   ------------------------------ 317.72 KiB/162.58 MiB
# ⠸ Preparing packages... (0/30)---------------- 14.82 KiB/184.17 MiB
# filelock                 ------------------------------ 8.79 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 30.90 KiB/87.85 KiB
# fsspec                   ------------------------------ 46.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 61.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 125.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 30.87 KiB/551.04 KiB
# regex                    ------------------------------ 242.61 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 219.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 301.44 KiB/1.14 MiB
# networkx                 ------------------------------ 30.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 301.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 30.91 KiB/3.10 MiB
# sympy                    ------------------------------ 30.88 KiB/6.01 MiB
# pillow                   ------------------------------ 14.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 76.08 KiB/9.77 MiB
# transformers             ------------------------------ 75.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 284.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 30.89 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 267.20 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 30.83 KiB/118.88 MiB
# triton                   ------------------------------ 317.72 KiB/162.58 MiB
# ⠸ Preparing packages... (0/30)---------------- 14.82 KiB/184.17 MiB
# filelock                 ------------------------------ 14.88 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 30.90 KiB/87.85 KiB
# fsspec                   ------------------------------ 46.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 67.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 125.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 46.87 KiB/551.04 KiB
# regex                    ------------------------------ 286.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 235.97 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 333.34 KiB/1.14 MiB
# networkx                 ------------------------------ 30.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 333.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 30.91 KiB/3.10 MiB
# sympy                    ------------------------------ 30.88 KiB/6.01 MiB
# pillow                   ------------------------------ 30.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 76.08 KiB/9.77 MiB
# transformers             ------------------------------ 91.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 316.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 62.89 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 300.88 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 30.83 KiB/118.88 MiB
# triton                   ------------------------------ 333.82 KiB/162.58 MiB
# ⠸ Preparing packages... (0/30)---------------- 265.90 KiB/184.17 MiB
# filelock                 ------------------------------ 14.88 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 30.90 KiB/87.85 KiB
# fsspec                   ------------------------------ 46.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 67.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 141.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 46.87 KiB/551.04 KiB
# regex                    ------------------------------ 334.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 235.97 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 381.36 KiB/1.14 MiB
# networkx                 ------------------------------ 30.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 381.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 46.91 KiB/3.10 MiB
# sympy                    ------------------------------ 30.88 KiB/6.01 MiB
# pillow                   ------------------------------ 30.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 76.08 KiB/9.77 MiB
# transformers             ------------------------------ 107.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 364.77 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 123.42 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 336.18 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 46.83 KiB/118.88 MiB
# triton                   ------------------------------ 353.87 KiB/162.58 MiB
# ⠼ Preparing packages... (0/30)---------------- 332.96 KiB/184.17 MiB
# filelock                 ------------------------------ 15.68 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 45.99 KiB/87.85 KiB
# fsspec                   ------------------------------ 62.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 83.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 141.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 62.87 KiB/551.04 KiB
# regex                    ------------------------------ 350.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 251.97 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 397.36 KiB/1.14 MiB
# networkx                 ------------------------------ 30.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 397.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 46.91 KiB/3.10 MiB
# sympy                    ------------------------------ 30.88 KiB/6.01 MiB
# pillow                   ------------------------------ 46.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 92.08 KiB/9.77 MiB
# transformers             ------------------------------ 107.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 396.77 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 139.42 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 352.18 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 46.83 KiB/118.88 MiB
# triton                   ------------------------------ 385.87 KiB/162.58 MiB
# ⠼ Preparing packages... (0/30)---------------- 364.96 KiB/184.17 MiB
# filelock                 ------------------------------ 15.68 KiB/15.68 KiB
# nvidia-nvtx-cu12         ------------------------------ 45.99 KiB/87.85 KiB
# fsspec                   ------------------------------ 62.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 83.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 141.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 62.87 KiB/551.04 KiB
# regex                    ------------------------------ 382.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 251.97 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 429.36 KiB/1.14 MiB
# networkx                 ------------------------------ 30.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 429.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 46.91 KiB/3.10 MiB
# sympy                    ------------------------------ 46.88 KiB/6.01 MiB
# pillow                   ------------------------------ 46.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 108.08 KiB/9.77 MiB
# transformers             ------------------------------ 123.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 402.13 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 367.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 384.18 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 46.83 KiB/118.88 MiB
# triton                   ------------------------------ 401.82 KiB/162.58 MiB
# ⠼ Preparing packages... (0/30)---------------- 396.96 KiB/184.17 MiB
# nvidia-nvtx-cu12         ------------------------------ 45.99 KiB/87.85 KiB
# fsspec                   ------------------------------ 62.88 KiB/194.62 KiB
# safetensors              ------------------------------ 14.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 83.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 141.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 62.87 KiB/551.04 KiB
# regex                    ------------------------------ 382.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 251.97 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 429.36 KiB/1.14 MiB
# networkx                 ------------------------------ 30.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 429.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 46.91 KiB/3.10 MiB
# sympy                    ------------------------------ 46.88 KiB/6.01 MiB
# pillow                   ------------------------------ 46.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 108.08 KiB/9.77 MiB
# transformers             ------------------------------ 123.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 402.13 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 367.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 384.18 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 46.83 KiB/118.88 MiB
# triton                   ------------------------------ 401.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 396.96 KiB/184.17 MiB
# ⠼ Preparing packages... (0/30)---------------- 413.97 KiB/255.11 MiB
# nvidia-nvtx-cu12         ------------------------------ 45.99 KiB/87.85 KiB
# fsspec                   ------------------------------ 62.88 KiB/194.62 KiB
# safetensors              ------------------------------ 30.91 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 83.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 141.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 62.87 KiB/551.04 KiB
# regex                    ------------------------------ 398.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 251.97 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 445.36 KiB/1.14 MiB
# networkx                 ------------------------------ 46.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 445.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 204.34 KiB/3.10 MiB
# sympy                    ------------------------------ 46.88 KiB/6.01 MiB
# pillow                   ------------------------------ 46.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 108.08 KiB/9.77 MiB
# transformers             ------------------------------ 123.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 418.13 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 399.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 412.88 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 46.83 KiB/118.88 MiB
# triton                   ------------------------------ 417.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 412.96 KiB/184.17 MiB
# ⠼ Preparing packages... (0/30)---------------- 445.97 KiB/255.11 MiB
# nvidia-nvtx-cu12         ------------------------------ 61.99 KiB/87.85 KiB
# fsspec                   ------------------------------ 77.12 KiB/194.62 KiB
# safetensors              ------------------------------ 351.47 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 99.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 157.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 76.41 KiB/551.04 KiB
# regex                    ------------------------------ 414.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 267.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 477.36 KiB/1.14 MiB
# networkx                 ------------------------------ 46.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 477.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 460.23 KiB/3.10 MiB
# sympy                    ------------------------------ 62.88 KiB/6.01 MiB
# pillow                   ------------------------------ 46.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 108.08 KiB/9.77 MiB
# transformers             ------------------------------ 123.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 450.03 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 415.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 428.88 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 46.83 KiB/118.88 MiB
# triton                   ------------------------------ 417.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 444.96 KiB/184.17 MiB
# ⠴ Preparing packages... (1/30)---------------- 461.97 KiB/255.11 MiB
# nvidia-nvtx-cu12         ------------------------------ 61.99 KiB/87.85 KiB
# fsspec                   ------------------------------ 93.12 KiB/194.62 KiB
# safetensors              ------------------------------ 463.47 KiB/474.45 KiB
# sentence-transformers    ------------------------------ 99.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 205.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 76.41 KiB/551.04 KiB
# regex                    ------------------------------ 451.74 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 271.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 509.25 KiB/1.14 MiB
# networkx                 ------------------------------ 62.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 509.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 476.34 KiB/3.10 MiB
# sympy                    ------------------------------ 62.88 KiB/6.01 MiB
# pillow                   ------------------------------ 46.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 140.08 KiB/9.77 MiB
# transformers             ------------------------------ 139.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 476.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 447.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 447.82 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 46.83 KiB/118.88 MiB
# triton                   ------------------------------ 417.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 460.96 KiB/184.17 MiB
# ⠴ Preparing packages... (1/30)---------------- 498.32 KiB/255.11 MiB
# nvidia-nvtx-cu12         ------------------------------ 61.99 KiB/87.85 KiB
# fsspec                   ------------------------------ 93.12 KiB/194.62 KiB
# sentence-transformers    ------------------------------ 115.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 205.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 76.41 KiB/551.04 KiB
# regex                    ------------------------------ 451.74 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 303.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 509.25 KiB/1.14 MiB
# networkx                 ------------------------------ 62.88 KiB/1.94 MiB
# hf-xet                   ------------------------------ 509.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 476.34 KiB/3.10 MiB
# sympy                    ------------------------------ 62.88 KiB/6.01 MiB
# pillow                   ------------------------------ 46.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 140.08 KiB/9.77 MiB
# transformers             ------------------------------ 155.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 476.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 447.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 476.88 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 46.83 KiB/118.88 MiB
# triton                   ------------------------------ 417.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 460.96 KiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 498.32 KiB/255.11 MiB
# ⠴ Preparing packages... (1/30)---------------- 524.86 KiB/273.89 MiB
# nvidia-nvtx-cu12         ------------------------------ 77.99 KiB/87.85 KiB
# fsspec                   ------------------------------ 93.12 KiB/194.62 KiB
# sentence-transformers    ------------------------------ 115.24 KiB/475.17 KiB
# mpmath                   ------------------------------ 234.67 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 92.41 KiB/551.04 KiB
# regex                    ------------------------------ 494.36 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 351.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 557.36 KiB/1.14 MiB
# networkx                 ------------------------------ 84.62 KiB/1.94 MiB
# hf-xet                   ------------------------------ 557.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 524.34 KiB/3.10 MiB
# sympy                    ------------------------------ 62.88 KiB/6.01 MiB
# pillow                   ------------------------------ 62.91 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 140.08 KiB/9.77 MiB
# transformers             ------------------------------ 177.62 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 540.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 495.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 508.88 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 62.83 KiB/118.88 MiB
# triton                   ------------------------------ 433.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 524.96 KiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 541.97 KiB/255.11 MiB
# ⠴ Preparing packages... (1/30)---------------- 540.86 KiB/273.89 MiB
# nvidia-nvtx-cu12         ------------------------------ 87.85 KiB/87.85 KiB
# fsspec                   ------------------------------ 125.12 KiB/194.62 KiB
# sentence-transformers    ------------------------------ 125.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 266.45 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 204.41 KiB/551.04 KiB
# regex                    ------------------------------ 542.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 385.82 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 606.92 KiB/1.14 MiB
# networkx                 ------------------------------ 116.51 KiB/1.94 MiB
# hf-xet                   ------------------------------ 605.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 572.34 KiB/3.10 MiB
# sympy                    ------------------------------ 75.44 KiB/6.01 MiB
# pillow                   ------------------------------ 110.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 172.08 KiB/9.77 MiB
# transformers             ------------------------------ 203.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 620.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 559.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 601.33 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 77.47 KiB/118.88 MiB
# triton                   ------------------------------ 609.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 588.96 KiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 605.97 KiB/255.11 MiB
# ⠴ Preparing packages... (1/30)---------------- 620.86 KiB/273.89 MiB
# fsspec                   ------------------------------ 125.12 KiB/194.62 KiB
# sentence-transformers    ------------------------------ 125.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 269.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 220.41 KiB/551.04 KiB
# regex                    ------------------------------ 574.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 399.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 638.92 KiB/1.14 MiB
# networkx                 ------------------------------ 116.51 KiB/1.94 MiB
# hf-xet                   ------------------------------ 642.54 KiB/3.04 MiB
# tokenizers               ------------------------------ 604.45 KiB/3.10 MiB
# sympy                    ------------------------------ 90.41 KiB/6.01 MiB
# pillow                   ------------------------------ 126.29 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 172.08 KiB/9.77 MiB
# transformers             ------------------------------ 219.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 636.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 591.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 601.33 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 93.47 KiB/118.88 MiB
# triton                   ------------------------------ 609.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 604.96 KiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 621.97 KiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 620.86 KiB/273.89 MiB
# ⠴ Preparing packages... (1/30)---------------- 638.51 KiB/274.86 MiB
# fsspec                   ------------------------------ 141.01 KiB/194.62 KiB
# sentence-transformers    ------------------------------ 157.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 381.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 252.41 KiB/551.04 KiB
# regex                    ------------------------------ 606.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 527.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 677.44 KiB/1.14 MiB
# networkx                 ------------------------------ 132.51 KiB/1.94 MiB
# hf-xet                   ------------------------------ 669.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 630.03 KiB/3.10 MiB
# sympy                    ------------------------------ 90.41 KiB/6.01 MiB
# pillow                   ------------------------------ 174.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 188.08 KiB/9.77 MiB
# transformers             ------------------------------ 251.02 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 655.21 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 623.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 620.88 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 125.47 KiB/118.88 MiB
# triton                   ------------------------------ 657.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 636.96 KiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 653.97 KiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 654.19 KiB/273.89 MiB
# ⠦ Preparing packages... (3/30)---------------- 670.51 KiB/274.86 MiB
# fsspec                   ------------------------------ 141.01 KiB/194.62 KiB
# sentence-transformers    ------------------------------ 173.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 397.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 252.41 KiB/551.04 KiB
# regex                    ------------------------------ 654.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 527.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 699.42 KiB/1.14 MiB
# networkx                 ------------------------------ 132.51 KiB/1.94 MiB
# hf-xet                   ------------------------------ 701.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 662.03 KiB/3.10 MiB
# sympy                    ------------------------------ 90.41 KiB/6.01 MiB
# pillow                   ------------------------------ 190.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 204.08 KiB/9.77 MiB
# transformers             ------------------------------ 367.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 684.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 671.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 654.09 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 589.47 KiB/118.88 MiB
# triton                   ------------------------------ 689.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 668.96 KiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 685.97 KiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 684.86 KiB/273.89 MiB
# ⠦ Preparing packages... (3/30)---------------- 702.51 KiB/274.86 MiB
# fsspec                   ------------------------------ 157.12 KiB/194.62 KiB
# sentence-transformers    ------------------------------ 173.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 397.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 252.41 KiB/551.04 KiB
# regex                    ------------------------------ 702.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 543.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 749.36 KiB/1.14 MiB
# networkx                 ------------------------------ 132.51 KiB/1.94 MiB
# hf-xet                   ------------------------------ 749.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 732.34 KiB/3.10 MiB
# sympy                    ------------------------------ 106.41 KiB/6.01 MiB
# pillow                   ------------------------------ 190.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 572.08 KiB/9.77 MiB
# transformers             ------------------------------ 383.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 748.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 735.53 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 716.88 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 701.37 KiB/118.88 MiB
# triton                   ------------------------------ 753.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 732.96 KiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 749.97 KiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 748.86 KiB/273.89 MiB
# ⠦ Preparing packages... (3/30)---------------- 782.41 KiB/274.86 MiB
# fsspec                   ------------------------------ 157.12 KiB/194.62 KiB
# sentence-transformers    ------------------------------ 173.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 397.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 252.41 KiB/551.04 KiB
# regex                    ------------------------------ 702.46 KiB/783.21 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 543.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 797.36 KiB/1.14 MiB
# networkx                 ------------------------------ 140.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 797.40 KiB/3.04 MiB
# tokenizers               ------------------------------ 732.34 KiB/3.10 MiB
# sympy                    ------------------------------ 106.41 KiB/6.01 MiB
# pillow                   ------------------------------ 190.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 748.08 KiB/9.77 MiB
# transformers             ------------------------------ 383.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 796.88 KiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 783.42 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 764.88 KiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 733.47 KiB/118.88 MiB
# triton                   ------------------------------ 801.82 KiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 780.96 KiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 800.63 KiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 796.86 KiB/273.89 MiB
# ⠦ Preparing packages... (3/30)---------------- 798.41 KiB/274.86 MiB
# fsspec                   ------------------------------ 194.62 KiB/194.62 KiB
# sentence-transformers    ------------------------------ 173.09 KiB/475.17 KiB
# ...
# nvidia-cusparselt-cu12   ------------------------------ 1.10 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.10 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.09 MiB/307.42 MiB
# ⠋ Preparing packages... (5/30)---------------- 1.12 MiB/566.81 MiB
# sentence-transformers    ------------------------------ 221.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 509.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 300.41 KiB/551.04 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 639.44 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 1.07 MiB/1.14 MiB
# networkx                 ------------------------------ 236.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 1.09 MiB/3.04 MiB
# tokenizers               ------------------------------ 1.11 MiB/3.10 MiB
# sympy                    ------------------------------ 138.41 KiB/6.01 MiB
# pillow                   ------------------------------ 238.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.10 MiB/9.77 MiB
# transformers             ------------------------------ 671.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.12 MiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 1.11 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.10 MiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 1.07 MiB/118.88 MiB
# triton                   ------------------------------ 1.12 MiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 1.10 MiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.15 MiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 1.15 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.15 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.12 MiB/307.42 MiB
# ⠙ Preparing packages... (5/30)---------------- 1.18 MiB/566.81 MiB
# sentence-transformers    ------------------------------ 237.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 509.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 300.41 KiB/551.04 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 655.44 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 1.07 MiB/1.14 MiB
# networkx                 ------------------------------ 236.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 1.09 MiB/3.04 MiB
# tokenizers               ------------------------------ 1.11 MiB/3.10 MiB
# sympy                    ------------------------------ 138.41 KiB/6.01 MiB
# pillow                   ------------------------------ 238.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.10 MiB/9.77 MiB
# transformers             ------------------------------ 690.40 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.12 MiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 1.11 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.10 MiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 1.07 MiB/118.88 MiB
# triton                   ------------------------------ 1.12 MiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 1.10 MiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.15 MiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 1.15 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.15 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.12 MiB/307.42 MiB
# ⠙ Preparing packages... (5/30)---------------- 1.18 MiB/566.81 MiB
# sentence-transformers    ------------------------------ 237.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 509.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 300.41 KiB/551.04 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 655.44 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 1.10 MiB/1.14 MiB
# networkx                 ------------------------------ 236.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 1.12 MiB/3.04 MiB
# tokenizers               ------------------------------ 1.13 MiB/3.10 MiB
# sympy                    ------------------------------ 138.41 KiB/6.01 MiB
# pillow                   ------------------------------ 238.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.12 MiB/9.77 MiB
# transformers             ------------------------------ 690.40 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.14 MiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 1.14 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.13 MiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 1.10 MiB/118.88 MiB
# triton                   ------------------------------ 1.12 MiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 1.12 MiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.17 MiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 1.18 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.17 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.15 MiB/307.42 MiB
# ⠙ Preparing packages... (5/30)---------------- 1.18 MiB/566.81 MiB
# sentence-transformers    ------------------------------ 253.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 509.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 316.41 KiB/551.04 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 655.44 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 1.13 MiB/1.14 MiB
# networkx                 ------------------------------ 252.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 1.14 MiB/3.04 MiB
# tokenizers               ------------------------------ 1.16 MiB/3.10 MiB
# sympy                    ------------------------------ 155.44 KiB/6.01 MiB
# pillow                   ------------------------------ 270.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.15 MiB/9.77 MiB
# transformers             ------------------------------ 706.40 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.18 MiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 1.17 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.16 MiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 1.12 MiB/118.88 MiB
# triton                   ------------------------------ 1.14 MiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 1.17 MiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.18 MiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 1.21 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.21 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.18 MiB/307.42 MiB
# ⠙ Preparing packages... (5/30)---------------- 1.21 MiB/566.81 MiB
# sentence-transformers    ------------------------------ 269.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 509.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 377.32 KiB/551.04 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 671.55 KiB/932.39 KiB
# nvidia-cufile-cu12       ------------------------------ 1.14 MiB/1.14 MiB
# networkx                 ------------------------------ 268.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 1.17 MiB/3.04 MiB
# tokenizers               ------------------------------ 1.18 MiB/3.10 MiB
# sympy                    ------------------------------ 187.44 KiB/6.01 MiB
# pillow                   ------------------------------ 286.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.18 MiB/9.77 MiB
# transformers             ------------------------------ 735.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.20 MiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 1.20 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.18 MiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 1.15 MiB/118.88 MiB
# triton                   ------------------------------ 1.19 MiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 1.19 MiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.21 MiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 1.24 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.24 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.21 MiB/307.42 MiB
# ⠙ Preparing packages... (5/30)---------------- 1.26 MiB/566.81 MiB
# sentence-transformers    ------------------------------ 269.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 509.41 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 377.32 KiB/551.04 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 671.55 KiB/932.39 KiB
# networkx                 ------------------------------ 268.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 1.18 MiB/3.04 MiB
# tokenizers               ------------------------------ 1.20 MiB/3.10 MiB
# sympy                    ------------------------------ 187.44 KiB/6.01 MiB
# pillow                   ------------------------------ 286.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.18 MiB/9.77 MiB
# transformers             ------------------------------ 751.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.20 MiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 1.21 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.18 MiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 1.17 MiB/118.88 MiB
# triton                   ------------------------------ 1.19 MiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 1.19 MiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.23 MiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 1.26 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.24 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.21 MiB/307.42 MiB
# nvidia-cublas-cu12       ------------------------------ 1.26 MiB/566.81 MiB
# ⠙ Preparing packages... (5/30)---------------- 1.17 MiB/674.02 MiB
# sentence-transformers    ------------------------------ 269.09 KiB/475.17 KiB
# mpmath                   ------------------------------ 523.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 377.32 KiB/551.04 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 687.55 KiB/932.39 KiB
# networkx                 ------------------------------ 284.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 1.20 MiB/3.04 MiB
# tokenizers               ------------------------------ 1.23 MiB/3.10 MiB
# sympy                    ------------------------------ 187.44 KiB/6.01 MiB
# pillow                   ------------------------------ 318.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.22 MiB/9.77 MiB
# transformers             ------------------------------ 751.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.21 MiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 1.24 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.21 MiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 1.20 MiB/118.88 MiB
# triton                   ------------------------------ 1.22 MiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 1.23 MiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.24 MiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 1.28 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.28 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.24 MiB/307.42 MiB
# nvidia-cublas-cu12       ------------------------------ 1.29 MiB/566.81 MiB
# ⠹ Preparing packages... (6/30)---------------- 1.20 MiB/674.02 MiB
# sentence-transformers    ------------------------------ 280.97 KiB/475.17 KiB
# mpmath                   ------------------------------ 523.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 377.32 KiB/551.04 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 687.55 KiB/932.39 KiB
# networkx                 ------------------------------ 284.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 1.25 MiB/3.04 MiB
# tokenizers               ------------------------------ 1.27 MiB/3.10 MiB
# sympy                    ------------------------------ 203.44 KiB/6.01 MiB
# pillow                   ------------------------------ 318.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.24 MiB/9.77 MiB
# transformers             ------------------------------ 767.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.26 MiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 1.29 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.26 MiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 1.24 MiB/118.88 MiB
# triton                   ------------------------------ 1.25 MiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 1.25 MiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.28 MiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 1.32 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.32 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.27 MiB/307.42 MiB
# nvidia-cublas-cu12       ------------------------------ 1.34 MiB/566.81 MiB
# ⠹ Preparing packages... (6/30)---------------- 1.24 MiB/674.02 MiB
# sentence-transformers    ------------------------------ 280.97 KiB/475.17 KiB
# huggingface-hub          ------------------------------ 377.32 KiB/551.04 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 687.55 KiB/932.39 KiB
# networkx                 ------------------------------ 284.67 KiB/1.94 MiB
# hf-xet                   ------------------------------ 1.26 MiB/3.04 MiB
# tokenizers               ------------------------------ 1.29 MiB/3.10 MiB
# sympy                    ------------------------------ 203.44 KiB/6.01 MiB
# pillow                   ------------------------------ 318.40 KiB/6.71 MiB
# nvidia-cuda-cupti-cu12   ------------------------------ 1.26 MiB/9.77 MiB
# transformers             ------------------------------ 767.13 KiB/11.44 MiB
# nvidia-nvjitlink-cu12    ------------------------------ 1.28 MiB/37.44 MiB
# nvidia-curand-cu12       ------------------------------ 1.32 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12   ------------------------------ 1.27 MiB/83.96 MiB
# nvidia-nvshmem-cu12      ------------------------------ 1.26 MiB/118.88 MiB
# triton                   ------------------------------ 1.28 MiB/162.58 MiB
# nvidia-cufft-cu12        ------------------------------ 1.29 MiB/184.17 MiB
# nvidia-cusolver-cu12     ------------------------------ 1.31 MiB/255.11 MiB
# nvidia-cusparselt-cu12   ------------------------------ 1.32 MiB/273.89 MiB
# nvidia-cusparse-cu12     ------------------------------ 1.34 MiB/274.86 MiB
# nvidia-nccl-cu12         ------------------------------ 1.30 MiB/307.42 MiB
# nvidia-cublas-cu12       ------------------------------ 1.37 MiB/566.81 MiB
# nvidia-cudnn-cu12        ------------------------------ 1.26 MiB/674.02 MiB
# torch                    ------------------------------ 844.39 KiB/858.06 MiB

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer('multi-qa-distilbert-cos-v1')

# %%
docs = [
    ["I just discovered the course, can I still join?"],
    ['I just found out about this program. Can I still enrol?'],
    ["you can join the course at any point of time"]
]


vectors = []
for d in docs:
    v = embedding_model.encode(d)
    vectors.append(v)

# %%
q1, q2, d = vectors

# %%
q1 = q1[0]
q2 = q2[0]
d = d[0]

# %%
q1.dot(q2)
# Out:
# np.float32(0.61739707)

# %%
q1.dot(d)
# Out:
# np.float32(0.72059387)

# %%
q2.dot(d)
# Out:
# np.float32(0.48841882)

# %%
# !uv add tqdm
# Out:
# Resolved 152 packages in 0.79ms
# Audited 147 packages in 1ms
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from tqdm.auto import tqdm

# %%
d  = documents[11]

# %%
d
# Out:
# {'text': "No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running.",
#  'section': 'General course-related questions',
#  'question': 'Certificate - Can I follow the course in a self-paced mode and get a certificate?',
#  'course': 'data-engineering-zoomcamp'}

# %%
text = d['question'] + ' ' + d['text']
text
# Out:
# "Certificate - Can I follow the course in a self-paced mode and get a certificate? No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running."

# %%
from tqdm.auto import tqdm

# %%
import numpy as np

# %%
embeddings = []

for d in tqdm(documents):
    text = d['question'] + ' ' + d['text']
    v = embedding_model.encode(text)
    embeddings.append(v)

embeddings = np.array(embeddings)
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]

# %%
embeddings.shape
# Out:
# (948, 768)

# %%
from minsearch import VectorSearch

# %%
vindex = VectorSearch(keyword_fields=['course'])
vindex.fit(embeddings, documents)

# %%
vindex.search(q2, filter_dict={'course': 'data-engineering-zoomcamp'}, num_results=5)
# Out:
# [{'text': "Yes, even if you don't register, you're still eligible to submit the homeworks.\nBe aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.",
#   'section': 'General course-related questions',
#   'question': 'Course - Can I still join the course after the start date?',
#   'course': 'data-engineering-zoomcamp'},
#  {'text': 'Yes, we will keep all the materials after the course finishes, so you can follow the course at your own pace after it finishes.\nYou can also continue looking at the homeworks and continue preparing for the next cohort. I guess you can also start working on your final capstone project.',
#   'section': 'General course-related questions',
#   'question': 'Course - Can I follow the course after it finishes?',
#   'course': 'data-engineering-zoomcamp'},
#  {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#   'section': 'General course-related questions',
#   'question': 'Course - When will the course start?',
#   'course': 'data-engineering-zoomcamp'},
#  {'text': "No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running.",
#   'section': 'General course-related questions',
#   'question': 'Certificate - Can I follow the course in a self-paced mode and get a certificate?',
#   'course': 'data-engineering-zoomcamp'},
#  {'text': 'Yes, the slack channel remains open and you can ask questions there. But always sDocker containers exit code w search the channel first and second, check the FAQ (this document), most likely all your questions are already answered here.\nYou can also tag the bot @ZoomcampQABot to help you conduct the search, but don’t rely on its answers 100%, it is pretty good though.',
#   'section': 'General course-related questions',
#   'question': 'Course - Can I get support if I take the course in the self-paced mode?',
#   'course': 'data-engineering-zoomcamp'}]

# %%
def vector_search(question):
    q = embedding_model.encode(question)

    return vindex.search(
        q,
        filter_dict={'course': 'data-engineering-zoomcamp'},
        num_results=5
    )

# %%
question = 'I just found out about this program. Can I still enrol?'
vector_search(question)
# Out:
# [{'text': "Yes, even if you don't register, you're still eligible to submit the homeworks.\nBe aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.",
#   'section': 'General course-related questions',
#   'question': 'Course - Can I still join the course after the start date?',
#   'course': 'data-engineering-zoomcamp'},
#  {'text': 'Yes, we will keep all the materials after the course finishes, so you can follow the course at your own pace after it finishes.\nYou can also continue looking at the homeworks and continue preparing for the next cohort. I guess you can also start working on your final capstone project.',
#   'section': 'General course-related questions',
#   'question': 'Course - Can I follow the course after it finishes?',
#   'course': 'data-engineering-zoomcamp'},
#  {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#   'section': 'General course-related questions',
#   'question': 'Course - When will the course start?',
#   'course': 'data-engineering-zoomcamp'},
#  {'text': "No, you can only get a certificate if you finish the course with a “live” cohort. We don't award certificates for the self-paced mode. The reason is you need to peer-review capstone(s) after submitting a project. You can only peer-review projects at the time the course is running.",
#   'section': 'General course-related questions',
#   'question': 'Certificate - Can I follow the course in a self-paced mode and get a certificate?',
#   'course': 'data-engineering-zoomcamp'},
#  {'text': 'Yes, the slack channel remains open and you can ask questions there. But always sDocker containers exit code w search the channel first and second, check the FAQ (this document), most likely all your questions are already answered here.\nYou can also tag the bot @ZoomcampQABot to help you conduct the search, but don’t rely on its answers 100%, it is pretty good though.',
#   'section': 'General course-related questions',
#   'question': 'Course - Can I get support if I take the course in the self-paced mode?',
#   'course': 'data-engineering-zoomcamp'}]

# %%
def rag(question):
    search_results = vector_search(question)
    user_prompt = build_prompt(question, search_results)
    return llm(user_prompt, instructions=instructions)

# %%
rag(question)
# Out:
# "Yes, you can still enroll and submit homework even if you didn't register before the course started. However, be mindful of deadlines for turning in final projects, so it’s advisable not to leave everything until the last minute."

# %%
def hybrid_search(question):
    r1 = search(question)
    r2 = vector_search(question)
    return r1 + r2
